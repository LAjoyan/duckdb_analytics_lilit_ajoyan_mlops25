# %%
import duckdb
# connect to duckdb database
with duckdb.connect("data/sakila.db") as conn:
   actor = conn.sql("from staging.actor;").df()

actor.head()
# Out:
#    actor_id first_name     last_name         last_update        _dlt_load_id  \
# 0       1.0   PENELOPE       GUINESS 2021-03-06 15:51:59  1764757783.6749265
# 1       2.0       NICK      WAHLBERG 2021-03-06 15:51:59  1764757783.6749265
# 2       3.0         ED         CHASE 2021-03-06 15:51:59  1764757783.6749265
# 3       4.0   JENNIFER         DAVIS 2021-03-06 15:51:59  1764757783.6749265
# 4       5.0     JOHNNY  LOLLOBRIGIDA 2021-03-06 15:51:59  1764757783.6749265
#
#           _dlt_id
# 0  O/U8HFV+0U5VQg
# 1  /RT6uePCNG9ktw
# 2  c2XGLOg2+PBiJA
# 3  7D/qoD8JXBSV9A
# 4  2qxsvSA5GxiLqw
